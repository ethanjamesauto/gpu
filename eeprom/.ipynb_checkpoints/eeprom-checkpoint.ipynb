# %% [markdown]
# Code for generating VGA data for an EEPROM. Used for testing a primitive VGA graphics generator.

# %%
import cv2
import numpy as np

# %%
def mapRange(value, inMin, inMax, outMin, outMax):
    return outMin + (((value - inMin) / (inMax - inMin)) * (outMax - outMin))

def rgb_to_hex(in_col):
    #for i in range(0, len(in_col)):
        #in_col[i] = mapRange(in_col[i], 0, 255, 0, 255)
    col = 0
    col += int(in_col[0] / 32) & 0b111
    col <<= 3
    col += int(in_col[1] / 32) & 0b111
    col <<= 2
    col += int(in_col[2] / 64) & 0b11
    return col

# %%
img = cv2.imread('High Sierra.jpg', cv2.IMREAD_UNCHANGED)
img = cv2.resize(img, (256, 240))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
sprite = np.empty((256, 256), dtype='int8')
for r in range(0, 256):
    for c in range(0, 256):
        try:
            col = rgb_to_hex(img[r][c])
        except:
            col = 0
        sprite[r][c] = col

# %%
screen = np.empty((256, 256, 3))
for r in range(0, sprite.shape[0]):
    for c in range(0, sprite.shape[1]):
        screen[r][c][0] = ((sprite[r][c] >> 6) & 0b11) / 3
        screen[r][c][1] = ((sprite[r][c] >> 2) & 0b111) / 7
        screen[r][c][2] = ((sprite[r][c]) & 0b11) / 3
        
import matplotlib.pyplot as plt
print(sprite.shape)
plt.figure(figsize=(2,2), dpi=700)
plt.axis('off')
plt.imshow(screen)
open('eeprom.bin', 'wb').write(sprite.tobytes())
# Out:
# (256, 256)
# 65536
